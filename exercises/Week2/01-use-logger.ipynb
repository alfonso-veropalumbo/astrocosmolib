# %%
# Include the parent directory in the path to import the module pyACC
import sys

pyACC_parent_dir = ... # Fill in the path to the parent directory of pyACC here
sys.path.append(pyACC_parent_dir)

from pyACC.helpers import Logger

# %%
alias = "" # Fill in your prompt here

# Setup the logger
logger = Logger(alias=alias)

# %%
# Print a INFO message 

logger("This is an INFO message")

# %%
# Print a warning message

logger.warning("This is a WARNING message")

# %%
# Print an error message

errorType = ... # Fill in the error type here
logger.error("This is an ERROR message", ErrorType=errorType)
